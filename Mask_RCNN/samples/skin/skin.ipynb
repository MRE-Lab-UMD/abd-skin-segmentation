# %%
import os
import sys
import time
import numpy as np
import imgaug 
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from pycocotools import mask as maskUtils
import zipfile
import urllib.request
import json
import shutil
from PIL import Image, ImageDraw

# %%
# Root directory of the project
ROOT_DIR = os.path.abspath("../../../Mask_RCNN/")
# Import Mask RCNN
# Import mrcnn libraries
sys.path.append(ROOT_DIR) 
from mrcnn.config import Config
import mrcnn.utils as utils
from mrcnn import visualize
import mrcnn.model as modellib
# Out:
# Using TensorFlow backend.

# %%
# Path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Directory to save logs and model checkpoints, if not provided
# through the command line argument --logs
DEFAULT_LOGS_DIR = os.path.join(ROOT_DIR, "logs")
DEFAULT_DATASET_YEAR = "2018"

# %%
dir = '../../../skin/'

# %%
############################################################
#  Configurations
############################################################

class SkinConfig(Config):
    """Configuration for training on the toy  dataset.
    Derives from the base Config class and overrides some values.
    """
    # Give the configuration a recognizable name
    NAME = "skin"

    # We use a GPU with 12GB memory, which can fit two images.
    # Adjust down if you use a smaller GPU.
    IMAGES_PER_GPU = 2

    # Number of classes (including background)
    NUM_CLASSES = 1 + 1  # Background + skin

    # Number of training steps per epoch
    STEPS_PER_EPOCH = 100
    
    # This is how often validation is run. If you are using too much hard drive space
    # on saved models (in the MODEL_DIR), try making this value larger.
    VALIDATION_STEPS = 5
    
    # Matterport originally used resnet101, but I downsized to fit it on my graphics card
    BACKBONE = 'resnet50'

    # Skip detections with < 90% confidence
#     DETECTION_MIN_CONFIDENCE = 0.9
     # To be honest, I haven't taken the time to figure out what these do
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 50 
    POST_NMS_ROIS_INFERENCE = 500 
    POST_NMS_ROIS_TRAINING = 1000 
    
    
config = SkinConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_bbox_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_mask_loss': 1.0, 'rpn_class_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               50
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           skin
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        500
# POST_NMS_ROIS_TRAINING         1000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               5
# WEIGHT_DECAY                   0.0001

# %%
c = SkinDataset()
c.load_data('../../../skin/train/instances_skin_2019.json','../../../skin/train/skin_train2019/')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1f46c4ce0d9c> in <module>
# ----> 1 c = SkinDataset()
#       2 c.load_data('../../../skin/train/instances_skin_2019.json','../../../skin/train/skin_train2019/')
#
# NameError: name 'SkinDataset' is not defined

# %%
class SkinDataset(utils.Dataset):
    
    def load_data(self, annotation_json, images_dir):
        """ Load the coco-like dataset from json
        Args:
            annotation_json: The path to the coco annotations json file
            images_dir: The directory holding the images referred to by the json file
        """
        # Load json from file
        json_file = open(annotation_json)
        coco_json = json.load(json_file)
        json_file.close()
        
        # Add the class names using the base method from utils.Dataset
        source_name = "skin"
        for category in coco_json['categories']:
            class_id = category['id']
            class_name = category['name']
#             print(class_name)
    
            if class_id < 1:
                print('Error: Class id for "{}" cannot be less than one. (0 is reserved for the background)'.format(class_name))
                return
            
            self.add_class(source_name, class_id, class_name)
            print('hi')
        
        # Get all annotations
        annotations = {}
        for annotation in coco_json['annotations']:
            image_id = annotation['image_id']
#             print(image_id)
        
            if image_id not in annotations:
                annotations[image_id] = []
            annotations[image_id].append(annotation)
#             print(annotations)
            
        
        # Get all images and add them to the dataset
        seen_images = {}
        for image in coco_json['images']:
            image_id = image['id']
            print(image)
            break

# %%
dataset_train = SkinDataset()
dataset_train.load_data('../../../skin/train/instances_skin_2019.json','../../../skin/train/skin_train2019/')
# dataset_train.prepare()
# Out:
# hi
# {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '542.jpeg', 'license': 1, 'id': 1}

# %%
#             print(image)
            if image_id in seen_images:
                print("Warning: Skipping duplicate image id: {}".format(image))
            else:
                seen_images[image_id] = image
                try:
                    image_file_name = image['file_name']
                    image_width = image['width']
                    image_height = image['height']
                except KeyError as key:
                    print("Warning: Skipping image (id: {}) with missing key: {}".format(image_id, key))
                
                image_path = os.path.abspath(os.path.join(images_dir, image_file_name))
                image_annotations = annotations[image_id]
                
                # Add the image using the base method from utils.Dataset
                self.add_image(
                    source=source_name,
                    image_id=image_id,
                    path=image_path,
                    width=image_width,
                    height=image_height,
                    annotations=image_annotations
                )
                
    def load_mask(self, image_id):
        """ Load instance masks for the given image.
        MaskRCNN expects masks in the form of a bitmap [height, width, instances].
        Args:
            image_id: The id of the image to load masks for
        Returns:
            masks: A bool array of shape [height, width, instance count] with
                one mask per instance.
            class_ids: a 1D array of class IDs of the instance masks.
        """
        image_info = self.image_info[image_id]
        annotations = image_info['annotations']
        instance_masks = []
        class_ids = []
        
        for annotation in annotations:
            class_id = annotation['category_id']
            mask = Image.new('1', (image_info['width'], image_info['height']))
            mask_draw = ImageDraw.ImageDraw(mask, '1')
            for segmentation in annotation['segmentation']:
                mask_draw.polygon(segmentation, fill=1)
                bool_array = np.array(mask) > 0
                instance_masks.append(bool_array)
                class_ids.append(class_id)

        mask = np.dstack(instance_masks)
        class_ids = np.array(class_ids, dtype=np.int32)
        
        return mask, class_ids

# %% [markdown]
# ## Creating Training and Validation Data

# %%
dataset_train = SkinDataset()
dataset_train.load_data('../../../skin/train/instances_skin_2019.json','../../../skin/train/skin_train2019/')
# dataset_train.prepare()
# Out:
# hi
# 1
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1022.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '903.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '385.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '212.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '138.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '977.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '987.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '648.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '283.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '94.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '861.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '601.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '81.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '812.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '265.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '995.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '407.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '672.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '561.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '516.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '706.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '539.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '547.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '409.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '398.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1016.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '543.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '975.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '715.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '233.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1089.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '239.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '948.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1099.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '351.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '119.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1005.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '532.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '732.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '896.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '759.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '501.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '128.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '908.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '404.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '713.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '192.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '897.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '535.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '117.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '282.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '36.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '124.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '346.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '883.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '687.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '287.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '395.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '523.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1086.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '554.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '797.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1003.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1105.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1046.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '35.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '435.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '389.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '307.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '173.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '727.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '226.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '869.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '153.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '74.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '796.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '154.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '167.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '954.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '318.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '686.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '399.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '273.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '789.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '971.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '305.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '802.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '696.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '507.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '571.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '843.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '934.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1042.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1049.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '801.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '656.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '992.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '264.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '393.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '176.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '923.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '578.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '95.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '577.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '654.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '912.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '77.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '719.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '381.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '218.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '297.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '942.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1074.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '827.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '387.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '693.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1004.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '482.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '471.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '649.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '401.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1043.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1011.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '489.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1006.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '473.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '747.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1064.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '627.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '803.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '728.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '55.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '764.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '538.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '26.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '781.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '949.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '621.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '324.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '461.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '844.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '451.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '907.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '65.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '262.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '364.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1001.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '456.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '845.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1097.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '741.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '813.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '626.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '41.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '102.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '834.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '836.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '775.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1077.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '761.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '772.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '928.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '152.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '894.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '178.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '906.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '278.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '275.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '837.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '718.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '487.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '739.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '765.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '688.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1026.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '807.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '573.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '955.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '529.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '666.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '374.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '616.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '223.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1041.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '497.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '978.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '695.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '935.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '445.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '349.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '422.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '211.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1096.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '684.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1092.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '596.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '582.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '885.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '901.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '289.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '201.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '734.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '963.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '544.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '717.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '671.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '379.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '663.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '808.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '319.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '427.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '151.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '205.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '644.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '729.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '257.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '936.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '927.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '878.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '245.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1032.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '253.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '285.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '725.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '655.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '806.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '575.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '312.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '175.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1098.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '818.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '877.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '887.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '39.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '534.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '235.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '599.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '299.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '87.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '537.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '625.jpeg', 'license': 1, 'id': 1}
# 1
# ...
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '918.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '924.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1037.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '477.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '433.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '925.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '98.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '367.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '617.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '308.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '277.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1029.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '12.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '506.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '396.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '66.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '848.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '466.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '182.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '259.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '636.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '863.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '38.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '18.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '198.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '564.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '139.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '148.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '474.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '386.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '615.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '569.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '14.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '22.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1108.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '964.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '78.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '744.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '377.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '866.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1008.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '89.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '637.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '202.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '166.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '244.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '763.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '779.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '112.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '946.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '414.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '32.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1116.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '838.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '165.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '62.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '269.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '325.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '448.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '986.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '388.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '347.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '54.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '412.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '411.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '335.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '833.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '88.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1002.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '17.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '236.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '15.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '574.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '463.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '21.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '933.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '882.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '359.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '1095.jpeg', 'license': 1, 'id': 1}
# 1
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'date_captured': '2019-02-11 18:56:40.397710', 'file_name': '177.jpeg', 'license': 1, 'id': 1}

# %%
dataset_val = SkinDataset()
dataset_val.load_data('../../../skin/val/instances_skin_2019.json','../../../skin/val/skin_val2019/')
dataset_val.prepare()
# Out:
# hi
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '1050.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '930.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '1070.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '800.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '220.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '1040.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '1010.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '100.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '20.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '510.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '190.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '710.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '590.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '750.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '900.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '140.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '120.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '690.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '850.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '910.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '460.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '330.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '480.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '420.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '970.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '40.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '170.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '550.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '840.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '60.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '1060.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '490.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '150.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '280.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '610.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '820.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '440.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '530.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '870.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '700.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '1080.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '810.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '270.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '580.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '730.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '310.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '560.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '1000.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '400.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '90.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '620.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '380.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '660.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '240.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '670.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '720.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '950.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '760.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '770.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '160.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '1110.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '10.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '70.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '880.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '520.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '370.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '340.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '890.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '540.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '320.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '430.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '1030.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '260.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '680.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '920.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '960.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '250.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '80.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '390.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '980.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '50.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '650.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '1090.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '350.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '740.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '990.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '630.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '450.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '230.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '640.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '1020.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '210.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '360.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '200.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '1100.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '830.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '130.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '30.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '500.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '860.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '940.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '780.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '300.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '180.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '570.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '290.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '790.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 576, 'coco_url': '', 'width': 768, 'file_name': '110.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '410.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}
# Warning: Skipping duplicate image id: {'flickr_url': '', 'height': 768, 'coco_url': '', 'width': 512, 'file_name': '470.jpeg', 'license': 1, 'date_captured': '2019-02-11 19:00:16.357148', 'id': 1}

# %% [markdown]
# # Display a few images from the training dataset¶

# %%
dataset = dataset_train
image_ids = np.random.choice(dataset.image_ids, 4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-7c1f06381e41> in <module>
#       1 dataset = dataset_train
# ----> 2 image_ids = np.random.choice(dataset.image_ids, 4)
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: a must be non-empty

# %%
dataset.image_ids
# Out:
# []

# %%
for image_id in image_ids:
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset.class_names)

# %% [markdown]
# # Create the Training Model and Train¶

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)

# %%
# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)

# %% [markdown]
# # Training
# Train in two stages:
#
#    * Only the heads. Here we're freezing all the backbone layers and training only the randomly initialized layers (i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, pass layers='heads' to the train() function.
#
#    * Fine-tune all layers. For this simple example it's not necessary, but we're including it to show the process. Simply pass layers="all to train all layers.

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
start_train = time.time()
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=4, 
            layers='heads')
end_train = time.time()
minutes = round((end_train - start_train) / 60, 2)
print(f'Training took {minutes} minutes')

# %%
# Fine tune all layers
# Passing layers="all" trains all layers. You can also 
# pass a regular expression to select which layers to
# train by name pattern.
start_train = time.time()
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE / 10,
            epochs=8, 
            layers="all")
end_train = time.time()
minutes = round((end_train - start_train) / 60, 2)
print(f'Training took {minutes} minutes')

# %% [markdown]
# # Prepare to run Inference

# %%
class InferenceConfig(CigButtsConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512
    DETECTION_MIN_CONFIDENCE = 0.85
    

inference_config = InferenceConfig()

# %%
# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

# %%
# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")
model_path = model.find_last()

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)

# %% [markdown]
# # Run Inference

# %%
import skimage
real_test_dir = '../../../datasets/cig_butts/real_test/'
image_paths = []
for filename in os.listdir(real_test_dir):
    if os.path.splitext(filename)[1].lower() in ['.png', '.jpg', '.jpeg']:
        image_paths.append(os.path.join(real_test_dir, filename))

for image_path in image_paths:
    img = skimage.io.imread(image_path)
    img_arr = np.array(img)
    results = model.detect([img_arr], verbose=1)
    r = results[0]
    visualize.display_instances(img, r['rois'], r['masks'], r['class_ids'], 
                                dataset_val.class_names, r['scores'], figsize=(5,5))
