# %%
import datetime
import json
import os
import re
import fnmatch
from PIL import Image
import numpy as np
from pycococreatortools import pycococreatortools
import matplotlib.pyplot as plt

ROOT_DIR = '../../../coco-abdomen/val/'
IMAGE_DIR = os.path.join(ROOT_DIR, "skin_val2019")
ANNOTATION_DIR = os.path.join(ROOT_DIR, "annotations")

INFO = {
    "description": "Skin Dataset",
    "url": "https://github.com/waspinator/pycococreator",
    "version": "0.1.0",
    "year": 2019,
    "contributor": "Anirudh",
    "date_created": datetime.datetime.utcnow().isoformat(' ')
}

LICENSES = [
    {
        "id": 1,
        "name": "Attribution-NonCommercial-ShareAlike License",
        "url": "http://creativecommons.org/licenses/by-nc-sa/2.0/"
    }
]

CATEGORIES = [
    {
        'id': 1,
        'name': 'skin',
        'supercategory': 'skin',
    },
]

def filter_for_jpeg(root, files):
    file_types = ['*.jpeg', '*.jpg']
    file_types = r'|'.join([fnmatch.translate(x) for x in file_types])
    files = [os.path.join(root, f) for f in files]
    files = [f for f in files if re.match(file_types, f)]
    
    return files

def filter_for_annotations(root, files, image_filename):
    file_types = ['*.png']
    file_types = r'|'.join([fnmatch.translate(x) for x in file_types])
    basename_no_extension = os.path.splitext(os.path.basename(image_filename))[0]
    file_name_prefix = basename_no_extension + '.*'
    files = [os.path.join(root, f) for f in files]
    files = [f for f in files if re.match(file_types, f)]
    files = [f for f in files if re.match(file_name_prefix, os.path.splitext(os.path.basename(f))[0])]

    return files

def main():

    coco_output = {
        "info": INFO,
        "licenses": LICENSES,
        "categories": CATEGORIES,
        "images": [],
        "annotations": []
    }

    image_id = 1
    segmentation_id = 1
    # filter for jpeg images
    for root, _, files in os.walk(IMAGE_DIR):
        image_files = filter_for_jpeg(root, files)

        # go through each image
        for image_filename in image_files:
            image = Image.open(image_filename)
            image_info = pycococreatortools.create_image_info(
                image_id, os.path.basename(image_filename), image.size)
            print(image_id)
            coco_output["images"].append(image_info)

            # filter for associated png annotations
            for root, _, files in os.walk(ANNOTATION_DIR):
                annotation_files = filter_for_annotations(root, files, image_filename)
                print(annotation_files)
                print(image_filename)
#                 print(files)
                # go through each associated annotation
                for annotation_filename in annotation_files:

                    if 'skin' in annotation_filename:
                        class_id = 1
                    category_info = {'id': class_id, 'is_crowd': 'crowd' in image_filename}
                    binary_mask = np.asarray(Image.open(annotation_filename)
                        .convert('1')).astype(np.uint8)

                    annotation_info = pycococreatortools.create_annotation_info(
                        segmentation_id, image_id, category_info, binary_mask,
                        image.size, tolerance=2)
                    print(image_id)
                    if annotation_info is not None:
                        coco_output["annotations"].append(annotation_info)    
                    segmentation_id = segmentation_id + 1
                    break
            image_id = image_id + 1

    with open('{}/instances_skin_val2019.json'.format(ROOT_DIR), 'w') as output_json_file:
        json.dump(coco_output, output_json_file)

# %%
if __name__ == "__main__":
    main()
# Out:
# 1
# ['../../../coco-abdomen/val/annotations/542_skin_542.png']
# ../../../coco-abdomen/val/skin_val2019/542.jpeg
# 1
# 2
# ['../../../coco-abdomen/val/annotations/600_skin_600.png']
# ../../../coco-abdomen/val/skin_val2019/600.jpeg
# 2
# 3
# ['../../../coco-abdomen/val/annotations/601_skin_601.png']
# ../../../coco-abdomen/val/skin_val2019/601.jpeg
# 3
# 4
# ['../../../coco-abdomen/val/annotations/561_skin_561.png']
# ../../../coco-abdomen/val/skin_val2019/561.jpeg
# 4
# 5
# ['../../../coco-abdomen/val/annotations/516_skin_516.png']
# ../../../coco-abdomen/val/skin_val2019/516.jpeg
# 5
# 6
# ['../../../coco-abdomen/val/annotations/539_skin_539.png']
# ../../../coco-abdomen/val/skin_val2019/539.jpeg
# 6
# 7
# ['../../../coco-abdomen/val/annotations/547_skin_547.png']
# ../../../coco-abdomen/val/skin_val2019/547.jpeg
# 7
# 8
# ['../../../coco-abdomen/val/annotations/543_skin_543.png']
# ../../../coco-abdomen/val/skin_val2019/543.jpeg
# 8
# 9
# ['../../../coco-abdomen/val/annotations/532_skin_532.png']
# ../../../coco-abdomen/val/skin_val2019/532.jpeg
# 9
# 10
# ['../../../coco-abdomen/val/annotations/501_skin_501.png']
# ../../../coco-abdomen/val/skin_val2019/501.jpeg
# 10
# 11
# ['../../../coco-abdomen/val/annotations/535_skin_535.png']
# ../../../coco-abdomen/val/skin_val2019/535.jpeg
# 11
# 12
# ['../../../coco-abdomen/val/annotations/523_skin_523.png']
# ../../../coco-abdomen/val/skin_val2019/523.jpeg
# 12
# 13
# ['../../../coco-abdomen/val/annotations/554_skin_554.png']
# ../../../coco-abdomen/val/skin_val2019/554.jpeg
# 13
# 14
# ['../../../coco-abdomen/val/annotations/507_skin_507.png']
# ../../../coco-abdomen/val/skin_val2019/507.jpeg
# 14
# 15
# ['../../../coco-abdomen/val/annotations/571_skin_571.png']
# ../../../coco-abdomen/val/skin_val2019/571.jpeg
# 15
# 16
# ['../../../coco-abdomen/val/annotations/578_skin_578.png']
# ../../../coco-abdomen/val/skin_val2019/578.jpeg
# 16
# 17
# ['../../../coco-abdomen/val/annotations/577_skin_577.png']
# ../../../coco-abdomen/val/skin_val2019/577.jpeg
# 17
# 18
# ['../../../coco-abdomen/val/annotations/510_skin_510.png']
# ../../../coco-abdomen/val/skin_val2019/510.jpeg
# 18
# 19
# ['../../../coco-abdomen/val/annotations/538_skin_538.png']
# ../../../coco-abdomen/val/skin_val2019/538.jpeg
# 19
# 20
# ['../../../coco-abdomen/val/annotations/590_skin_590.png']
# ../../../coco-abdomen/val/skin_val2019/590.jpeg
# 20
# 21
# ['../../../coco-abdomen/val/annotations/621_skin_621.png']
# ../../../coco-abdomen/val/skin_val2019/621.jpeg
# 21
# 22
# ['../../../coco-abdomen/val/annotations/573_skin_573.png']
# ../../../coco-abdomen/val/skin_val2019/573.jpeg
# 22
# 23
# ['../../../coco-abdomen/val/annotations/529_skin_529.png']
# ../../../coco-abdomen/val/skin_val2019/529.jpeg
# 23
# 24
# ['../../../coco-abdomen/val/annotations/616_skin_616.png']
# ../../../coco-abdomen/val/skin_val2019/616.jpeg
# 24
# 25
# ['../../../coco-abdomen/val/annotations/596_skin_596.png']
# ../../../coco-abdomen/val/skin_val2019/596.jpeg
# 25
# 26
# ['../../../coco-abdomen/val/annotations/582_skin_582.png']
# ../../../coco-abdomen/val/skin_val2019/582.jpeg
# 26
# 27
# ['../../../coco-abdomen/val/annotations/544_skin_544.png']
# ../../../coco-abdomen/val/skin_val2019/544.jpeg
# 27
# 28
# ['../../../coco-abdomen/val/annotations/575_skin_575.png']
# ../../../coco-abdomen/val/skin_val2019/575.jpeg
# 28
# 29
# ['../../../coco-abdomen/val/annotations/534_skin_534.png']
# ../../../coco-abdomen/val/skin_val2019/534.jpeg
# 29
# 30
# ['../../../coco-abdomen/val/annotations/599_skin_599.png']
# ../../../coco-abdomen/val/skin_val2019/599.jpeg
# 30
# 31
# ['../../../coco-abdomen/val/annotations/537_skin_537.png']
# ../../../coco-abdomen/val/skin_val2019/537.jpeg
# 31
# 32
# ['../../../coco-abdomen/val/annotations/611_skin_611.png']
# ../../../coco-abdomen/val/skin_val2019/611.jpeg
# 32
# 33
# ['../../../coco-abdomen/val/annotations/549_skin_549.png']
# ../../../coco-abdomen/val/skin_val2019/549.jpeg
# 33
# 34
# ['../../../coco-abdomen/val/annotations/607_skin_607.png']
# ../../../coco-abdomen/val/skin_val2019/607.jpeg
# 34
# 35
# ['../../../coco-abdomen/val/annotations/550_skin_550.png']
# ../../../coco-abdomen/val/skin_val2019/550.jpeg
# 35
# 36
# ['../../../coco-abdomen/val/annotations/502_skin_502.png']
# ../../../coco-abdomen/val/skin_val2019/502.jpeg
# 36
# 37
# ['../../../coco-abdomen/val/annotations/572_skin_572.png']
# ../../../coco-abdomen/val/skin_val2019/572.jpeg
# 37
# 38
# ['../../../coco-abdomen/val/annotations/587_skin_587.png']
# ../../../coco-abdomen/val/skin_val2019/587.jpeg
# 38
# 39
# ['../../../coco-abdomen/val/annotations/525_skin_525.png']
# ../../../coco-abdomen/val/skin_val2019/525.jpeg
# 39
# 40
# ['../../../coco-abdomen/val/annotations/565_skin_565.png']
# ../../../coco-abdomen/val/skin_val2019/565.jpeg
# 40
# 41
# ['../../../coco-abdomen/val/annotations/610_skin_610.png']
# ../../../coco-abdomen/val/skin_val2019/610.jpeg
# 41
# 42
# ['../../../coco-abdomen/val/annotations/562_skin_562.png']
# ../../../coco-abdomen/val/skin_val2019/562.jpeg
# 42
# 43
# ['../../../coco-abdomen/val/annotations/602_skin_602.png']
# ../../../coco-abdomen/val/skin_val2019/602.jpeg
# 43
# 44
# ['../../../coco-abdomen/val/annotations/566_skin_566.png']
# ../../../coco-abdomen/val/skin_val2019/566.jpeg
# 44
# 45
# ['../../../coco-abdomen/val/annotations/604_skin_604.png']
# ../../../coco-abdomen/val/skin_val2019/604.jpeg
# 45
# 46
# ['../../../coco-abdomen/val/annotations/530_skin_530.png']
# ../../../coco-abdomen/val/skin_val2019/530.jpeg
# 46
# 47
# ['../../../coco-abdomen/val/annotations/595_skin_595.png']
# ../../../coco-abdomen/val/skin_val2019/595.jpeg
# 47
# 48
# ['../../../coco-abdomen/val/annotations/586_skin_586.png']
# ../../../coco-abdomen/val/skin_val2019/586.jpeg
# 48
# 49
# ['../../../coco-abdomen/val/annotations/559_skin_559.png']
# ../../../coco-abdomen/val/skin_val2019/559.jpeg
# 49
# 50
# ['../../../coco-abdomen/val/annotations/519_skin_519.png']
# ../../../coco-abdomen/val/skin_val2019/519.jpeg
# 50
# 51
# ['../../../coco-abdomen/val/annotations/579_skin_579.png']
# ../../../coco-abdomen/val/skin_val2019/579.jpeg
# 51
# 52
# ['../../../coco-abdomen/val/annotations/522_skin_522.png']
# ../../../coco-abdomen/val/skin_val2019/522.jpeg
# 52
# 53
# ['../../../coco-abdomen/val/annotations/581_skin_581.png']
# ../../../coco-abdomen/val/skin_val2019/581.jpeg
# 53
# 54
# ['../../../coco-abdomen/val/annotations/555_skin_555.png']
# ../../../coco-abdomen/val/skin_val2019/555.jpeg
# 54
# 55
# ['../../../coco-abdomen/val/annotations/533_skin_533.png']
# ../../../coco-abdomen/val/skin_val2019/533.jpeg
# 55
# 56
# ['../../../coco-abdomen/val/annotations/580_skin_580.png']
# ../../../coco-abdomen/val/skin_val2019/580.jpeg
# 56
# 57
# ['../../../coco-abdomen/val/annotations/589_skin_589.png']
# ../../../coco-abdomen/val/skin_val2019/589.jpeg
# 57
# 58
# ['../../../coco-abdomen/val/annotations/584_skin_584.png']
# ../../../coco-abdomen/val/skin_val2019/584.jpeg
# 58
# 59
# ['../../../coco-abdomen/val/annotations/558_skin_558.png']
# ../../../coco-abdomen/val/skin_val2019/558.jpeg
# 59
# 60
# ['../../../coco-abdomen/val/annotations/560_skin_560.png']
# ../../../coco-abdomen/val/skin_val2019/560.jpeg
# 60
# 61
# ['../../../coco-abdomen/val/annotations/613_skin_613.png']
# ../../../coco-abdomen/val/skin_val2019/613.jpeg
# 61
# 62
# ['../../../coco-abdomen/val/annotations/608_skin_608.png']
# ../../../coco-abdomen/val/skin_val2019/608.jpeg
# 62
# 63
# ['../../../coco-abdomen/val/annotations/503_skin_503.png']
# ../../../coco-abdomen/val/skin_val2019/503.jpeg
# 63
# 64
# ['../../../coco-abdomen/val/annotations/620_skin_620.png']
# ../../../coco-abdomen/val/skin_val2019/620.jpeg
# 64
# 65
# ['../../../coco-abdomen/val/annotations/585_skin_585.png']
# ../../../coco-abdomen/val/skin_val2019/585.jpeg
# 65
# 66
# ['../../../coco-abdomen/val/annotations/521_skin_521.png']
# ../../../coco-abdomen/val/skin_val2019/521.jpeg
# 66
# 67
# ['../../../coco-abdomen/val/annotations/603_skin_603.png']
# ../../../coco-abdomen/val/skin_val2019/603.jpeg
# 67
# 68
# ['../../../coco-abdomen/val/annotations/531_skin_531.png']
# ../../../coco-abdomen/val/skin_val2019/531.jpeg
# 68
# 69
# ['../../../coco-abdomen/val/annotations/545_skin_545.png']
# ../../../coco-abdomen/val/skin_val2019/545.jpeg
# 69
# 70
# ['../../../coco-abdomen/val/annotations/619_skin_619.png']
# ../../../coco-abdomen/val/skin_val2019/619.jpeg
# 70
# 71
# ['../../../coco-abdomen/val/annotations/513_skin_513.png']
# ../../../coco-abdomen/val/skin_val2019/513.jpeg
# 71
# 72
# ['../../../coco-abdomen/val/annotations/518_skin_518.png']
# ../../../coco-abdomen/val/skin_val2019/518.jpeg
# 72
# 73
# ['../../../coco-abdomen/val/annotations/546_skin_546.png']
# ../../../coco-abdomen/val/skin_val2019/546.jpeg
# 73
# 74
# ['../../../coco-abdomen/val/annotations/614_skin_614.png']
# ../../../coco-abdomen/val/skin_val2019/614.jpeg
# 74
# 75
# ['../../../coco-abdomen/val/annotations/592_skin_592.png']
# ../../../coco-abdomen/val/skin_val2019/592.jpeg
# 75
# 76
# ['../../../coco-abdomen/val/annotations/598_skin_598.png']
# ../../../coco-abdomen/val/skin_val2019/598.jpeg
# 76
# 77
# ['../../../coco-abdomen/val/annotations/553_skin_553.png']
# ../../../coco-abdomen/val/skin_val2019/553.jpeg
# 77
# 78
# ['../../../coco-abdomen/val/annotations/520_skin_520.png']
# ../../../coco-abdomen/val/skin_val2019/520.jpeg
# 78
# 79
# ['../../../coco-abdomen/val/annotations/515_skin_515.png']
# ../../../coco-abdomen/val/skin_val2019/515.jpeg
# 79
# 80
# ['../../../coco-abdomen/val/annotations/567_skin_567.png']
# ../../../coco-abdomen/val/skin_val2019/567.jpeg
# 80
# 81
# ['../../../coco-abdomen/val/annotations/551_skin_551.png']
# ../../../coco-abdomen/val/skin_val2019/551.jpeg
# 81
# 82
# ['../../../coco-abdomen/val/annotations/568_skin_568.png']
# ../../../coco-abdomen/val/skin_val2019/568.jpeg
# 82
# 83
# ['../../../coco-abdomen/val/annotations/540_skin_540.png']
# ../../../coco-abdomen/val/skin_val2019/540.jpeg
# 83
# 84
# ['../../../coco-abdomen/val/annotations/512_skin_512.png']
# ../../../coco-abdomen/val/skin_val2019/512.jpeg
# 84
# 85
# ['../../../coco-abdomen/val/annotations/576_skin_576.png']
# ../../../coco-abdomen/val/skin_val2019/576.jpeg
# 85
# 86
# ['../../../coco-abdomen/val/annotations/597_skin_597.png']
# ../../../coco-abdomen/val/skin_val2019/597.jpeg
# 86
# 87
# ['../../../coco-abdomen/val/annotations/511_skin_511.png']
# ../../../coco-abdomen/val/skin_val2019/511.jpeg
# 87
# 88
# ['../../../coco-abdomen/val/annotations/588_skin_588.png']
# ../../../coco-abdomen/val/skin_val2019/588.jpeg
# 88
# 89
# ['../../../coco-abdomen/val/annotations/509_skin_509.png']
# ../../../coco-abdomen/val/skin_val2019/509.jpeg
# 89
# 90
# ['../../../coco-abdomen/val/annotations/541_skin_541.png']
# ../../../coco-abdomen/val/skin_val2019/541.jpeg
# 90
# 91
# ['../../../coco-abdomen/val/annotations/528_skin_528.png']
# ../../../coco-abdomen/val/skin_val2019/528.jpeg
# 91
# 92
# ['../../../coco-abdomen/val/annotations/563_skin_563.png']
# ../../../coco-abdomen/val/skin_val2019/563.jpeg
# 92
# 93
# ['../../../coco-abdomen/val/annotations/618_skin_618.png']
# ../../../coco-abdomen/val/skin_val2019/618.jpeg
# 93
# 94
# ['../../../coco-abdomen/val/annotations/591_skin_591.png']
# ../../../coco-abdomen/val/skin_val2019/591.jpeg
# 94
# 95
# ['../../../coco-abdomen/val/annotations/606_skin_606.png']
# ../../../coco-abdomen/val/skin_val2019/606.jpeg
# 95
# 96
# ['../../../coco-abdomen/val/annotations/508_skin_508.png']
# ../../../coco-abdomen/val/skin_val2019/508.jpeg
# 96
# 97
# ['../../../coco-abdomen/val/annotations/548_skin_548.png']
# ../../../coco-abdomen/val/skin_val2019/548.jpeg
# 97
# 98
# ['../../../coco-abdomen/val/annotations/612_skin_612.png']
# ../../../coco-abdomen/val/skin_val2019/612.jpeg
# 98
# 99
# ['../../../coco-abdomen/val/annotations/505_skin_505.png']
# ../../../coco-abdomen/val/skin_val2019/505.jpeg
# 99
# 100
# ['../../../coco-abdomen/val/annotations/609_skin_609.png']
# ../../../coco-abdomen/val/skin_val2019/609.jpeg
# 100
# 101
# ['../../../coco-abdomen/val/annotations/583_skin_583.png']
# ../../../coco-abdomen/val/skin_val2019/583.jpeg
# 101
# 102
# ['../../../coco-abdomen/val/annotations/556_skin_556.png']
# ../../../coco-abdomen/val/skin_val2019/556.jpeg
# 102
# 103
# ['../../../coco-abdomen/val/annotations/536_skin_536.png']
# ../../../coco-abdomen/val/skin_val2019/536.jpeg
# 103
# 104
# ['../../../coco-abdomen/val/annotations/527_skin_527.png']
# ../../../coco-abdomen/val/skin_val2019/527.jpeg
# 104
# 105
# ['../../../coco-abdomen/val/annotations/524_skin_524.png']
# ../../../coco-abdomen/val/skin_val2019/524.jpeg
# 105
# 106
# ['../../../coco-abdomen/val/annotations/514_skin_514.png']
# ../../../coco-abdomen/val/skin_val2019/514.jpeg
# 106
# 107
# ['../../../coco-abdomen/val/annotations/504_skin_504.png']
# ../../../coco-abdomen/val/skin_val2019/504.jpeg
# 107
# 108
# ['../../../coco-abdomen/val/annotations/593_skin_593.png']
# ../../../coco-abdomen/val/skin_val2019/593.jpeg
# 108
# 109
# ['../../../coco-abdomen/val/annotations/517_skin_517.png']
# ../../../coco-abdomen/val/skin_val2019/517.jpeg
# 109
# 110
# ['../../../coco-abdomen/val/annotations/526_skin_526.png']
# ../../../coco-abdomen/val/skin_val2019/526.jpeg
# 110
# 111
# ['../../../coco-abdomen/val/annotations/594_skin_594.png']
# ../../../coco-abdomen/val/skin_val2019/594.jpeg
# 111
# 112
# ['../../../coco-abdomen/val/annotations/605_skin_605.png']
# ../../../coco-abdomen/val/skin_val2019/605.jpeg
# 112
# 113
# ['../../../coco-abdomen/val/annotations/557_skin_557.png']
# ../../../coco-abdomen/val/skin_val2019/557.jpeg
# 113
# 114
# ['../../../coco-abdomen/val/annotations/552_skin_552.png']
# ../../../coco-abdomen/val/skin_val2019/552.jpeg
# 114
# 115
# ['../../../coco-abdomen/val/annotations/617_skin_617.png']
# ../../../coco-abdomen/val/skin_val2019/617.jpeg
# 115
# 116
# ['../../../coco-abdomen/val/annotations/506_skin_506.png']
# ../../../coco-abdomen/val/skin_val2019/506.jpeg
# 116
# 117
# ['../../../coco-abdomen/val/annotations/564_skin_564.png']
# ../../../coco-abdomen/val/skin_val2019/564.jpeg
# 117
# 118
# ['../../../coco-abdomen/val/annotations/615_skin_615.png']
# ../../../coco-abdomen/val/skin_val2019/615.jpeg
# 118
# 119
# ['../../../coco-abdomen/val/annotations/569_skin_569.png']
# ../../../coco-abdomen/val/skin_val2019/569.jpeg
# 119
# 120
# ['../../../coco-abdomen/val/annotations/570_skin_570.png']
# ../../../coco-abdomen/val/skin_val2019/570.jpeg
# 120
# 121
# ['../../../coco-abdomen/val/annotations/574_skin_574.png']
# ../../../coco-abdomen/val/skin_val2019/574.jpeg
# 121
