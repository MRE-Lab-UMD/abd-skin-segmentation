# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from datetime import datetime
from packaging import version

import os
import sys
import time
import random
import warnings

import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
from skimage.io import imread, imshow
from skimage.transform import resize

import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from keras import backend as K
from keras.utils import multi_gpu_model
from keras import optimizers
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.python.eager import context

# Specify Image Dimensions
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed

print("TensorFlow version: ", tf.__version__)
# Out:
# TensorFlow version:  1.14.0

# %% [markdown]
# Function for computing the masks' pixel-to-pixel accuracy, takes as input 2D masks and 2D predictions
# (Label 1 corresponds to skin, and 0 to non-skin)

# %%
def acc_comp(msk, preds_test_t):
    
    mean_acc = np.zeros(1)
    mean_TP = np.zeros(1)
    mean_TN = np.zeros(1)
    mean_FP = np.zeros(1)
    mean_FN = np.zeros(1)
    
    for j in range(msk.shape[0]):
        act = msk[j]
        pr = preds_test_t[j].reshape(IMG_WIDTH, IMG_HEIGHT)
    
        c = act == pr 
        d = act & pr 
        e = act | pr 
        neg = act.sum()
        pos = (IMG_WIDTH*IMG_HEIGHT)-act.sum()
    
        TP = round(float(d.sum()),6)
        FP = round(float(pr.sum()-d.sum()),6)
        TN = round(float((IMG_WIDTH*IMG_HEIGHT)-e.sum()),6)
        FN = round(float(e.sum()-pr.sum()),6)
        acc = round(float(c.sum())/(IMG_WIDTH*IMG_HEIGHT),6)

        #acc2 = float(TP+TN)/(TP+TN+FP+FN)  Used to double-check computations
        mean_TP = np.append([mean_TP],TP)
        mean_TN = np.append([mean_TN],TN)
        mean_acc = np.append([mean_acc],acc)
        mean_FP = np.append([mean_FP],FP)
        mean_FN = np.append([mean_FN],FN)
    
    mean_acc = mean_acc[1:]
    mean_TP = mean_TP[1:]
    mean_TN = mean_TN[1:]
    mean_FP = mean_FP[1:]
    mean_FN = mean_FN[1:]
    
    avg = round(mean_acc.sum()/msk.shape[0],6)
    std = round(np.std(mean_acc),6)
    overall_TP = round(mean_TP.sum()/msk.shape[0],6)
    overall_TN = round(mean_TN.sum()/msk.shape[0],6)
    
    return (mean_acc,std,mean_TP,mean_TN,mean_FP,mean_FN)

# %% [markdown]
# Class for extracting time elapsed per training epoch

# %%
class TimingCallback(Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

cb = TimingCallback()

# %% [markdown]
# Intersection-over-Union (IoU) metric, can be tracked instead of the accuracy during training

# %%
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %% [markdown]
# A) Get the training data (original images + masks). The images and masks must have the same labelling. Add the original images' path to TRAIN_PATH, and the masks' path to MASK_PATH.

# %%
# # Dataset 1: HGR
# TRAIN_PATH1 = ['../Input/Skin_Datasets/Dataset1_HGR/original_images/']
# MASK_PATH1 = ['../Input/Skin_Datasets/Dataset1_HGR/skin_masks/']
# train_ids1 = next(os.walk(TRAIN_PATH1[0]))[2]
# mask_ids1 = next(os.walk(MASK_PATH1[0]))[2]
# train_ids1.sort()
# mask_ids1.sort()
# TRAIN_PATH1 = TRAIN_PATH1*len(train_ids1)
# MASK_PATH1 = MASK_PATH1*len(train_ids1)

# # Dataset 2: TDSD
# TRAIN_PATH5 = ['../Input/Skin_Datasets/Dataset2_TDSD/original_images/']
# MASK_PATH5 = ['../Input/Skin_Datasets/Dataset2_TDSD/skin_masks/']
# train_ids5 = next(os.walk(TRAIN_PATH5[0]))[2]
# mask_ids5 = next(os.walk(MASK_PATH5[0]))[2]
# train_ids5.sort()
# mask_ids5.sort()
# TRAIN_PATH5 = TRAIN_PATH5*len(train_ids5)
# MASK_PATH5 = MASK_PATH5*len(train_ids5)

# # Dataset 3: Schmugge
# TRAIN_PATH6 = ['../Input/Skin_Datasets/Dataset3_Schmugge/original_images/']
# MASK_PATH6 = ['../Input/Skin_Datasets/Dataset3_Schmugge/skin_masks/']
# train_ids6 = next(os.walk(TRAIN_PATH6[0]))[2]
# mask_ids6 = next(os.walk(MASK_PATH6[0]))[2]
# train_ids6.sort()
# mask_ids6.sort()
# TRAIN_PATH6 = TRAIN_PATH6*len(train_ids6)
# MASK_PATH6 = MASK_PATH6*len(train_ids6)

# # Dataset 4: Pratheepan
# TRAIN_PATH2 = ['../Input/Skin_Datasets/Dataset4_Pratheepan/original_images/']
# MASK_PATH2 = ['../Input/Skin_Datasets/Dataset4_Pratheepan/skin_masks/']
# train_ids2 = next(os.walk(TRAIN_PATH2[0]))[2]
# mask_ids2 = next(os.walk(MASK_PATH2[0]))[2]
# train_ids2.sort()
# mask_ids2.sort()
# TRAIN_PATH2 = TRAIN_PATH2*len(train_ids2)
# MASK_PATH2 = MASK_PATH2*len(train_ids2)

# # Dataset 5: VDM
# TRAIN_PATH3 = ['../Input/Skin_Datasets/Dataset5_VDM/original_images/']
# MASK_PATH3 = ['../Input/Skin_Datasets/Dataset5_VDM/skin_masks/']
# train_id3 = next(os.walk(TRAIN_PATH3[0]))[2]
# mask_id3 = next(os.walk(MASK_PATH3[0]))[2]
# train_id3.sort()
# mask_id3.sort()
# train_ids3 = train_id3[1:]
# mask_ids3 = mask_id3[1:]
# TRAIN_PATH3 = TRAIN_PATH3*len(train_ids3)
# MASK_PATH3 = MASK_PATH3*len(train_ids3)

# # Dataset 6: SFA
# TRAIN_PATH4 = ['../Input/Skin_Datasets/Dataset6_SFA/original_images/']
# MASK_PATH4 = ['../Input/Skin_Datasets/Dataset6_SFA/skin_masks/']
# train_ids4 = next(os.walk(TRAIN_PATH4[0]))[2]
# mask_ids4 = next(os.walk(MASK_PATH4[0]))[2]
# train_ids4.sort()
# mask_ids4.sort()
# TRAIN_PATH4 = TRAIN_PATH4*len(train_ids4)
# MASK_PATH4 = MASK_PATH4*len(train_ids4)

# # Dataset 7: FSD
# TRAIN_PATH7 = ['../Input/Skin_Datasets/Dataset7_FSD/original_images/']
# MASK_PATH7 = ['../Input/Skin_Datasets/Dataset7_FSD/skin_masks/']
# train_ids7 = next(os.walk(TRAIN_PATH7[0]))[2]
# mask_ids7 = next(os.walk(MASK_PATH7[0]))[2]
# train_ids7.sort()
# mask_ids7.sort()
# TRAIN_PATH7 = TRAIN_PATH7*len(train_ids7)
# MASK_PATH7 = MASK_PATH7*len(train_ids7)

# # # Dataset 8: ABDOMEN
# TRAIN_PATH8 = ['../Input/Skin_Datasets/Dataset8_Abdomen/train/skin_train2019/']
# MASK_PATH8 = ['../Input/Skin_Datasets/Dataset8_Abdomen/train/annotations/']
# train_ids8 = next(os.walk(TRAIN_PATH8[0]))[2]
# mask_ids8 = next(os.walk(MASK_PATH8[0]))[2]
# train_ids8.sort()
# mask_ids8.sort()

# TRAIN_PATH8 = TRAIN_PATH8*len(train_ids8)
# MASK_PATH8 = MASK_PATH8*len(train_ids8)

# # Combine everything
# TRAIN_PATH = np.concatenate((TRAIN_PATH1,TRAIN_PATH2,TRAIN_PATH3,TRAIN_PATH4,TRAIN_PATH5, TRAIN_PATH6,TRAIN_PATH7,TRAIN_PATH8))
# MASK_PATH = np.concatenate((MASK_PATH1,MASK_PATH2,MASK_PATH3,MASK_PATH4,MASK_PATH5,MASK_PATH6,MASK_PATH7,MASK_PATH8))
# train_ids = np.concatenate((train_ids1,train_ids2,train_ids3,train_ids4,train_ids5,train_ids6,train_ids7,train_ids8))
# mask_ids = np.concatenate((mask_ids1,mask_ids2,mask_ids3,mask_ids4,mask_ids5,mask_ids6,mask_ids7,mask_ids8))

# %% [markdown]
# B) Shuffle the data and resize

# %%
# X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
# Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1))
# print('Getting and resizing train images and masks ... ')
# sys.stdout.flush()
# g = list(range(0,len(train_ids)))
# np.random.shuffle(g)

# strs_original = ["" for x in range(len(train_ids))]
# strs_mask = ["" for x in range(len(train_ids))]
# pathmsk = MASK_PATH[0] + mask_ids[0]
# for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
#     strs_mask[n] = MASK_PATH[n] + mask_ids[n]
#     strs_original[n] = TRAIN_PATH[n] + train_ids[n]
    
# for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
#     path = strs_original[g[n]]
#     img = imread(path)[:,:,:IMG_CHANNELS]
#     img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
#     X_train[n] = img
    
#     path = strs_mask[g[n]]
#     img = imread(path)
#     if img.ndim == 3:
#         img = img[:,:,1]
#     img = np.expand_dims(resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
#                                       preserve_range=True), axis=-1)
#     if (np.unique(img).size) > 2:
#         img = img > 30     # Important, needed to make labels 0's and 1's only 
#     else:
#         img = img > 0
#     Y_train[n] = img

# %% [markdown]
# ### To Avoid running the above two block again you can simply save the np arrays for convience by running the block below

# %%
# np.save("X_data",X_train)
# np.save("Y_data",Y_train)

# %%
# X_train = np.load('./X_data_abdomen_new.npy')
# Y_train = np.load('./Y_data_abdomen_new.npy')

# %%
X_train = np.load('./X_train_final.npy')
Y_train = np.load('./Y_train_final.npy')

# %% [markdown]
# C) Make sure the masks correspond to the original images

# %%
ix = random.randint(0, len(X_train))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()

# %% [markdown]
# D) Construct the UNET model

# %%
def skin_model():
    # Specify Image Dimensions
    IMG_WIDTH = 128
    IMG_HEIGHT = 128
    IMG_CHANNELS = 3
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    s = Lambda(lambda x: x) (inputs)

    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (s)
    c1 = Dropout(0.1) (c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c1)
    p1 = MaxPooling2D((2, 2)) (c1)

    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p1)
    c2 = Dropout(0.1) (c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c2)
    p2 = MaxPooling2D((2, 2)) (c2)

    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p2)
    c3 = Dropout(0.2) (c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c3)
    p3 = MaxPooling2D((2, 2)) (c3)

    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p3)
    c4 = Dropout(0.2) (c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c4)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

    c5 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p4)
    c5 = Dropout(0.2) (c5)
    c5 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c5)
    p5 = MaxPooling2D(pool_size=(2, 2)) (c5)

    c6 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p5)
    c6 = Dropout(0.3) (c6)
    c6 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c6)

    u7 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c5])
    c7 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u7)
    c7 = Dropout(0.2) (c7)
    c7 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c7)

    u8 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c4])
    c8 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u8)
    c8 = Dropout(0.2) (c8)
    c8 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c8)

    u9 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c3])
    c9 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u9)
    c9 = Dropout(0.1) (c9)
    c9 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c9)

    u10 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c9)
    u10 = concatenate([u10, c2], axis=3)
    c10 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u10)
    c10 = Dropout(0.1) (c10)
    c10 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c10)

    u11 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c10)
    u11 = concatenate([u11, c1], axis=3)
    c11 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u11)
    c11 = Dropout(0.1) (c11)
    c11 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c11)

    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c11)

    model = Model(inputs=[inputs], outputs=[outputs])
    model = multi_gpu_model(model, gpus=4)
    optimize = optimizers.Adam(lr = 0.001)
    model.compile(optimizer=optimize, loss='binary_crossentropy', metrics=['acc'])
    return model

# %% [markdown]
# ## E) Fit the model to the training data

# %%
# earlystopper = EarlyStopping(patience=30, verbose=1)
# checkpointer = ModelCheckpoint('attempt2crossvalk-5.h5', verbose=1, save_best_only=True)

# %%
class TrainValTensorBoard(TensorBoard):
    def __init__(self, fold, log_dir='./logs/kfold-unet/', **kwargs):
        self.val_log_dir = os.path.join(log_dir, 'validation_fold_'+ str(fold))
        training_log_dir = os.path.join(log_dir, 'training_fold_'+ str(fold))
        super(TrainValTensorBoard, self).__init__(training_log_dir, **kwargs)

    def set_model(self, model):
        if context.executing_eagerly():
            self.val_writer = tf.contrib.summary.create_file_writer(self.val_log_dir)
        else:
            self.val_writer = tf.summary.FileWriter(self.val_log_dir)
        super(TrainValTensorBoard, self).set_model(model)

    def _write_custom_summaries(self, step, logs=None):
        logs = logs or {}
        val_logs = {k.replace('val_', ''): v for k, v in logs.items() if 'val_' in k}
        if context.executing_eagerly():
            with self.val_writer.as_default(), tf.contrib.summary.always_record_summaries():
                for name, value in val_logs.items():
                    tf.contrib.summary.scalar(name, value.item(), step=step)
        else:
            for name, value in val_logs.items():
                summary = tf.Summary()
                summary_value = summary.value.add()
                summary_value.simple_value = value.item()
                summary_value.tag = name
                self.val_writer.add_summary(summary, step)
        self.val_writer.flush()

        logs = {k: v for k, v in logs.items() if not 'val_' in k}
        super(TrainValTensorBoard, self)._write_custom_summaries(step, logs)

    def on_train_end(self, logs=None):
        super(TrainValTensorBoard, self).on_train_end(logs)
        self.val_writer.close()

# %% [markdown]
# ## Manual K Fold for k=10

# %%
from sklearn.model_selection import StratifiedKFold
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
kfold = StratifiedKFold(n_splits=2, shuffle=True, random_state=seed)
y = np.random.choice([0, 1], size=(X_train.shape[0],))

# %%
# Summarize history for loss
def plotting(results,inp):
    plt.plot(results.history['loss'])
#     plt.plot(results.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
#     plt.legend(['train', 'test'], loc='upper left')
    plt.savefig('crossvalloss'+inp)
    plt.show()

    # Summarize history for mean_iou
    plt.plot(results.history['acc'])
#     plt.plot(results.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
#     plt.legend(['train', 'test'], loc='upper left')
    plt.savefig('crossvalaccu'+inp)
    plt.show()

# %%
i=1
cvscores = []
for train_index,test_index in kfold.split(np.zeros(y.shape),y):
    model = skin_model()
    checkpointer = ModelCheckpoint('fold_'+ str(i) + '.h5', verbose=1)
    results = model.fit(X_train[train_index], Y_train[train_index], batch_size=64, epochs=200, shuffle=True,
                        callbacks=[checkpointer, cb,TrainValTensorBoard(write_graph=False, fold = i)])
    plotting(results,str(i))
    i=i+1
    scores = model.evaluate(X_train[test_index], Y_train[test_index], verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
    break
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# Epoch 1/200
# 4400/4400 [==============================] - 17s 4ms/step - loss: 0.9535 - acc: 0.7704
#
# Epoch 00001: saving model to fold_1.h5
# Epoch 2/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.3432 - acc: 0.8496
#
# Epoch 00002: saving model to fold_1.h5
# Epoch 3/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.2877 - acc: 0.8803
#
# Epoch 00003: saving model to fold_1.h5
# Epoch 4/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.2427 - acc: 0.9014
#
# Epoch 00004: saving model to fold_1.h5
# Epoch 5/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.2199 - acc: 0.9126
#
# Epoch 00005: saving model to fold_1.h5
# Epoch 6/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1994 - acc: 0.9224
#
# Epoch 00006: saving model to fold_1.h5
# Epoch 7/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1861 - acc: 0.9283
#
# Epoch 00007: saving model to fold_1.h5
# Epoch 8/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1822 - acc: 0.9292
#
# Epoch 00008: saving model to fold_1.h5
# Epoch 9/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1730 - acc: 0.9330
#
# Epoch 00009: saving model to fold_1.h5
# Epoch 10/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1625 - acc: 0.9374
#
# Epoch 00010: saving model to fold_1.h5
# Epoch 11/200
# 4400/4400 [==============================] - 4s 1ms/step - loss: 0.1663 - acc: 0.9359
#
# Epoch 00011: saving model to fold_1.h5
# Epoch 12/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1555 - acc: 0.9403
#
# Epoch 00012: saving model to fold_1.h5
# Epoch 13/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1504 - acc: 0.9425
#
# Epoch 00013: saving model to fold_1.h5
# Epoch 14/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1461 - acc: 0.9438
#
# Epoch 00014: saving model to fold_1.h5
# Epoch 15/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1428 - acc: 0.9452
#
# Epoch 00015: saving model to fold_1.h5
# Epoch 16/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1345 - acc: 0.9482
#
# Epoch 00016: saving model to fold_1.h5
# Epoch 17/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1269 - acc: 0.9510
#
# Epoch 00017: saving model to fold_1.h5
# Epoch 18/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1221 - acc: 0.9528
#
# Epoch 00018: saving model to fold_1.h5
# Epoch 19/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1209 - acc: 0.9537
#
# Epoch 00019: saving model to fold_1.h5
# Epoch 20/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1158 - acc: 0.9554
#
# Epoch 00020: saving model to fold_1.h5
# Epoch 21/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1248 - acc: 0.9521
#
# Epoch 00021: saving model to fold_1.h5
# Epoch 22/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1192 - acc: 0.9543
#
# Epoch 00022: saving model to fold_1.h5
# Epoch 23/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1133 - acc: 0.9566
#
# Epoch 00023: saving model to fold_1.h5
# Epoch 24/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1127 - acc: 0.9570
#
# Epoch 00024: saving model to fold_1.h5
# Epoch 25/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1052 - acc: 0.9596
#
# Epoch 00025: saving model to fold_1.h5
# Epoch 26/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1009 - acc: 0.9614
#
# Epoch 00026: saving model to fold_1.h5
# Epoch 27/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0979 - acc: 0.9623
#
# Epoch 00027: saving model to fold_1.h5
# Epoch 28/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0981 - acc: 0.9626
#
# Epoch 00028: saving model to fold_1.h5
# Epoch 29/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0946 - acc: 0.9638
#
# Epoch 00029: saving model to fold_1.h5
# Epoch 30/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0927 - acc: 0.9646
#
# Epoch 00030: saving model to fold_1.h5
# Epoch 31/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0916 - acc: 0.9651A: 0s - loss: 0.0915 - acc: 0.965
#
# Epoch 00031: saving model to fold_1.h5
# Epoch 32/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0958 - acc: 0.9635
#
# Epoch 00032: saving model to fold_1.h5
# Epoch 33/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0919 - acc: 0.9649
#
# Epoch 00033: saving model to fold_1.h5
# Epoch 34/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0934 - acc: 0.9645
#
# Epoch 00034: saving model to fold_1.h5
# Epoch 35/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0957 - acc: 0.9632
#
# Epoch 00035: saving model to fold_1.h5
# Epoch 36/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0861 - acc: 0.9671
#
# Epoch 00036: saving model to fold_1.h5
# Epoch 37/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0909 - acc: 0.9652
#
# Epoch 00037: saving model to fold_1.h5
# Epoch 38/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0877 - acc: 0.9664
#
# Epoch 00038: saving model to fold_1.h5
# Epoch 39/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0813 - acc: 0.9691
#
# Epoch 00039: saving model to fold_1.h5
# Epoch 40/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0800 - acc: 0.9693
#
# Epoch 00040: saving model to fold_1.h5
# Epoch 41/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0806 - acc: 0.9691
#
# Epoch 00041: saving model to fold_1.h5
# Epoch 42/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0793 - acc: 0.9697
#
# Epoch 00042: saving model to fold_1.h5
# Epoch 43/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0747 - acc: 0.9713
#
# Epoch 00043: saving model to fold_1.h5
# Epoch 44/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0729 - acc: 0.9720
#
# Epoch 00044: saving model to fold_1.h5
# Epoch 45/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0740 - acc: 0.9716
#
# Epoch 00045: saving model to fold_1.h5
# Epoch 46/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0735 - acc: 0.9717
#
# Epoch 00046: saving model to fold_1.h5
# Epoch 47/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0752 - acc: 0.9713
#
# Epoch 00047: saving model to fold_1.h5
# Epoch 48/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0882 - acc: 0.9670
#
# Epoch 00048: saving model to fold_1.h5
# Epoch 49/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0811 - acc: 0.9691
#
# Epoch 00049: saving model to fold_1.h5
# Epoch 50/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0767 - acc: 0.9707
#
# Epoch 00050: saving model to fold_1.h5
# Epoch 51/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0858 - acc: 0.9677
#
# Epoch 00051: saving model to fold_1.h5
# Epoch 52/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0733 - acc: 0.9721
#
# Epoch 00052: saving model to fold_1.h5
# Epoch 53/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0687 - acc: 0.9736
#
# Epoch 00053: saving model to fold_1.h5
# Epoch 54/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0678 - acc: 0.9739
#
# Epoch 00054: saving model to fold_1.h5
# Epoch 55/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0669 - acc: 0.9743
#
# Epoch 00055: saving model to fold_1.h5
# Epoch 56/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0677 - acc: 0.9740
#
# Epoch 00056: saving model to fold_1.h5
# Epoch 57/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0644 - acc: 0.9752
#
# Epoch 00057: saving model to fold_1.h5
# Epoch 58/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0643 - acc: 0.9752
#
# Epoch 00058: saving model to fold_1.h5
# Epoch 59/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0640 - acc: 0.9754
#
# Epoch 00059: saving model to fold_1.h5
# Epoch 60/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0652 - acc: 0.9750
#
# Epoch 00060: saving model to fold_1.h5
# Epoch 61/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0655 - acc: 0.9749
#
# Epoch 00061: saving model to fold_1.h5
# Epoch 62/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0645 - acc: 0.9754
#
# Epoch 00062: saving model to fold_1.h5
# Epoch 63/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0631 - acc: 0.9757
#
# Epoch 00063: saving model to fold_1.h5
# Epoch 64/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0623 - acc: 0.9760
#
# Epoch 00064: saving model to fold_1.h5
# Epoch 65/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0619 - acc: 0.9763
#
# Epoch 00065: saving model to fold_1.h5
# Epoch 66/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0629 - acc: 0.9759
#
# Epoch 00066: saving model to fold_1.h5
# Epoch 67/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0623 - acc: 0.9760
#
# Epoch 00067: saving model to fold_1.h5
# Epoch 68/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0615 - acc: 0.9763
#
# Epoch 00068: saving model to fold_1.h5
# Epoch 69/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0775 - acc: 0.9710
#
# Epoch 00069: saving model to fold_1.h5
# Epoch 70/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0875 - acc: 0.9674
#
# Epoch 00070: saving model to fold_1.h5
# Epoch 71/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0992 - acc: 0.9632
#
# Epoch 00071: saving model to fold_1.h5
# Epoch 72/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0696 - acc: 0.9734
#
# Epoch 00072: saving model to fold_1.h5
# Epoch 73/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0708 - acc: 0.9731
#
# Epoch 00073: saving model to fold_1.h5
# Epoch 74/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0632 - acc: 0.9757
#
# Epoch 00074: saving model to fold_1.h5
# Epoch 75/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0605 - acc: 0.9767
#
# Epoch 00075: saving model to fold_1.h5
# Epoch 76/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0591 - acc: 0.9772
#
# Epoch 00076: saving model to fold_1.h5
# Epoch 77/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0579 - acc: 0.9777
#
# Epoch 00077: saving model to fold_1.h5
# Epoch 78/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0575 - acc: 0.9778
#
# Epoch 00078: saving model to fold_1.h5
# Epoch 79/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0677 - acc: 0.9742
#
# Epoch 00079: saving model to fold_1.h5
# Epoch 80/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0599 - acc: 0.9770
#
# Epoch 00080: saving model to fold_1.h5
# Epoch 81/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0621 - acc: 0.9761
#
# Epoch 00081: saving model to fold_1.h5
# Epoch 82/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0580 - acc: 0.9777
#
# Epoch 00082: saving model to fold_1.h5
# Epoch 83/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0562 - acc: 0.9783
#
# Epoch 00083: saving model to fold_1.h5
# Epoch 84/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0555 - acc: 0.9785
#
# Epoch 00084: saving model to fold_1.h5
# Epoch 85/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0556 - acc: 0.9785
#
# Epoch 00085: saving model to fold_1.h5
# Epoch 86/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0554 - acc: 0.9786
#
# Epoch 00086: saving model to fold_1.h5
# Epoch 87/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0544 - acc: 0.9789
#
# Epoch 00087: saving model to fold_1.h5
# Epoch 88/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0540 - acc: 0.9790
#
# Epoch 00088: saving model to fold_1.h5
# Epoch 89/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0530 - acc: 0.9794
#
# Epoch 00089: saving model to fold_1.h5
# Epoch 90/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0527 - acc: 0.9796
#
# Epoch 00090: saving model to fold_1.h5
# Epoch 91/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0534 - acc: 0.9793
#
# Epoch 00091: saving model to fold_1.h5
# Epoch 92/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0526 - acc: 0.9796
#
# Epoch 00092: saving model to fold_1.h5
# Epoch 93/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0694 - acc: 0.9739
#
# Epoch 00093: saving model to fold_1.h5
# Epoch 94/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0967 - acc: 0.9641
#
# Epoch 00094: saving model to fold_1.h5
# Epoch 95/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0730 - acc: 0.9722
#
# Epoch 00095: saving model to fold_1.h5
# Epoch 96/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0622 - acc: 0.9762
#
# Epoch 00096: saving model to fold_1.h5
# Epoch 97/200
# 4400/4400 [==============================] - 4s 1ms/step - loss: 0.0605 - acc: 0.9767
#
# Epoch 00097: saving model to fold_1.h5
# Epoch 98/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0577 - acc: 0.9778
#
# Epoch 00098: saving model to fold_1.h5
# Epoch 99/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0549 - acc: 0.9788
#
# Epoch 00099: saving model to fold_1.h5
# Epoch 100/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0539 - acc: 0.9792
#
# Epoch 00100: saving model to fold_1.h5
# Epoch 101/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0530 - acc: 0.9795
#
# Epoch 00101: saving model to fold_1.h5
# Epoch 102/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0525 - acc: 0.9796
#
# Epoch 00102: saving model to fold_1.h5
# Epoch 103/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0554 - acc: 0.9787
#
# Epoch 00103: saving model to fold_1.h5
# Epoch 104/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0540 - acc: 0.9791
#
# Epoch 00104: saving model to fold_1.h5
# Epoch 105/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0521 - acc: 0.9798
#
# Epoch 00105: saving model to fold_1.h5
# Epoch 106/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0514 - acc: 0.9801
#
# Epoch 00106: saving model to fold_1.h5
# Epoch 107/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0509 - acc: 0.9802
#
# Epoch 00107: saving model to fold_1.h5
# Epoch 108/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0510 - acc: 0.9802
#
# Epoch 00108: saving model to fold_1.h5
# Epoch 109/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0503 - acc: 0.9805
#
# Epoch 00109: saving model to fold_1.h5
# Epoch 110/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0499 - acc: 0.9806
#
# Epoch 00110: saving model to fold_1.h5
# Epoch 111/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0498 - acc: 0.9806
#
# Epoch 00111: saving model to fold_1.h5
# Epoch 112/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0493 - acc: 0.9808
#
# Epoch 00112: saving model to fold_1.h5
# Epoch 113/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0493 - acc: 0.9808
#
# Epoch 00113: saving model to fold_1.h5
# Epoch 114/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0497 - acc: 0.9806
#
# Epoch 00114: saving model to fold_1.h5
# Epoch 115/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0487 - acc: 0.9810
#
# Epoch 00115: saving model to fold_1.h5
# Epoch 116/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0494 - acc: 0.9808
#
# Epoch 00116: saving model to fold_1.h5
# Epoch 117/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0515 - acc: 0.9801
#
# Epoch 00117: saving model to fold_1.h5
# Epoch 118/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0520 - acc: 0.9799
#
# Epoch 00118: saving model to fold_1.h5
# Epoch 119/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0497 - acc: 0.9807
#
# Epoch 00119: saving model to fold_1.h5
# Epoch 120/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0488 - acc: 0.9810
#
# Epoch 00120: saving model to fold_1.h5
# Epoch 121/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0482 - acc: 0.9812
#
# Epoch 00121: saving model to fold_1.h5
# Epoch 122/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0667 - acc: 0.9751
#
# Epoch 00122: saving model to fold_1.h5
# Epoch 123/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0670 - acc: 0.9748
#
# Epoch 00123: saving model to fold_1.h5
# Epoch 124/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0594 - acc: 0.9773
#
# Epoch 00124: saving model to fold_1.h5
# Epoch 125/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0577 - acc: 0.9780
#
# Epoch 00125: saving model to fold_1.h5
# Epoch 126/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0570 - acc: 0.9781
#
# Epoch 00126: saving model to fold_1.h5
# Epoch 127/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0530 - acc: 0.9796
#
# Epoch 00127: saving model to fold_1.h5
# Epoch 128/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0536 - acc: 0.9793
#
# Epoch 00128: saving model to fold_1.h5
# Epoch 129/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0504 - acc: 0.9805
#
# Epoch 00129: saving model to fold_1.h5
# Epoch 130/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0508 - acc: 0.9804
#
# Epoch 00130: saving model to fold_1.h5
# Epoch 131/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0496 - acc: 0.9807
#
# Epoch 00131: saving model to fold_1.h5
# Epoch 132/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0490 - acc: 0.9810
#
# Epoch 00132: saving model to fold_1.h5
# Epoch 133/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0486 - acc: 0.9811
#
# Epoch 00133: saving model to fold_1.h5
# Epoch 134/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0474 - acc: 0.9815
#
# Epoch 00134: saving model to fold_1.h5
# Epoch 135/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0476 - acc: 0.9815
#
# Epoch 00135: saving model to fold_1.h5
# Epoch 136/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0473 - acc: 0.9816
#
# Epoch 00136: saving model to fold_1.h5
# Epoch 137/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0467 - acc: 0.9818
#
# Epoch 00137: saving model to fold_1.h5
# Epoch 138/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0465 - acc: 0.9819
#
# Epoch 00138: saving model to fold_1.h5
# Epoch 139/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0466 - acc: 0.9818
#
# Epoch 00139: saving model to fold_1.h5
# Epoch 140/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0472 - acc: 0.9816
#
# Epoch 00140: saving model to fold_1.h5
# Epoch 141/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0465 - acc: 0.9819
#
# Epoch 00141: saving model to fold_1.h5
# Epoch 142/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0464 - acc: 0.9819
#
# Epoch 00142: saving model to fold_1.h5
# Epoch 143/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0463 - acc: 0.9819
#
# Epoch 00143: saving model to fold_1.h5
# Epoch 144/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0470 - acc: 0.9817
#
# Epoch 00144: saving model to fold_1.h5
# Epoch 145/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0459 - acc: 0.9821
#
# Epoch 00145: saving model to fold_1.h5
# Epoch 146/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0455 - acc: 0.9822
#
# Epoch 00146: saving model to fold_1.h5
# Epoch 147/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0473 - acc: 0.9816
#
# Epoch 00147: saving model to fold_1.h5
# Epoch 148/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0463 - acc: 0.9820
#
# Epoch 00148: saving model to fold_1.h5
# Epoch 149/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0460 - acc: 0.9821
#
# Epoch 00149: saving model to fold_1.h5
# Epoch 150/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0461 - acc: 0.9821
#
# Epoch 00150: saving model to fold_1.h5
# Epoch 151/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0470 - acc: 0.9817
#
# Epoch 00151: saving model to fold_1.h5
# Epoch 152/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0494 - acc: 0.9808
#
# Epoch 00152: saving model to fold_1.h5
# Epoch 153/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0470 - acc: 0.9817
#
# Epoch 00153: saving model to fold_1.h5
# Epoch 154/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0492 - acc: 0.9809
#
# Epoch 00154: saving model to fold_1.h5
# Epoch 155/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0524 - acc: 0.9798
#
# Epoch 00155: saving model to fold_1.h5
# Epoch 156/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0487 - acc: 0.9812
#
# Epoch 00156: saving model to fold_1.h5
# Epoch 157/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0506 - acc: 0.9805
#
# Epoch 00157: saving model to fold_1.h5
# Epoch 158/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0628 - acc: 0.9764
#
# Epoch 00158: saving model to fold_1.h5
# Epoch 159/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.1039 - acc: 0.9626
#
# Epoch 00159: saving model to fold_1.h5
# Epoch 160/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0878 - acc: 0.9678
#
# Epoch 00160: saving model to fold_1.h5
# Epoch 161/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0779 - acc: 0.9708
#
# Epoch 00161: saving model to fold_1.h5
# Epoch 162/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0583 - acc: 0.9778
#
# Epoch 00162: saving model to fold_1.h5
# Epoch 163/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0532 - acc: 0.9794
#
# Epoch 00163: saving model to fold_1.h5
# Epoch 164/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0505 - acc: 0.9804
#
# Epoch 00164: saving model to fold_1.h5
# Epoch 165/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0488 - acc: 0.9811
#
# Epoch 00165: saving model to fold_1.h5
# Epoch 166/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0483 - acc: 0.9813
#
# Epoch 00166: saving model to fold_1.h5
# Epoch 167/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0482 - acc: 0.9813
#
# Epoch 00167: saving model to fold_1.h5
# Epoch 168/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0473 - acc: 0.9816
#
# Epoch 00168: saving model to fold_1.h5
# Epoch 169/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0466 - acc: 0.9819
#
# Epoch 00169: saving model to fold_1.h5
# Epoch 170/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0458 - acc: 0.9822
#
# Epoch 00170: saving model to fold_1.h5
# Epoch 171/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0457 - acc: 0.9822
#
# Epoch 00171: saving model to fold_1.h5
# Epoch 172/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0450 - acc: 0.9824
#
# Epoch 00172: saving model to fold_1.h5
# Epoch 173/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0446 - acc: 0.9826
#
# Epoch 00173: saving model to fold_1.h5
# Epoch 174/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0445 - acc: 0.9826
#
# Epoch 00174: saving model to fold_1.h5
# Epoch 175/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0443 - acc: 0.9826
#
# Epoch 00175: saving model to fold_1.h5
# Epoch 176/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0444 - acc: 0.9827
#
# Epoch 00176: saving model to fold_1.h5
# Epoch 177/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0445 - acc: 0.9827
#
# Epoch 00177: saving model to fold_1.h5
# Epoch 178/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0433 - acc: 0.9830
#
# Epoch 00178: saving model to fold_1.h5
# Epoch 179/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0434 - acc: 0.9830
#
# Epoch 00179: saving model to fold_1.h5
# Epoch 180/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0436 - acc: 0.9830
#
# Epoch 00180: saving model to fold_1.h5
# Epoch 181/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0436 - acc: 0.9829
#
# Epoch 00181: saving model to fold_1.h5
# Epoch 182/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0431 - acc: 0.9832
#
# Epoch 00182: saving model to fold_1.h5
# Epoch 183/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0433 - acc: 0.9831
#
# Epoch 00183: saving model to fold_1.h5
# Epoch 184/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0432 - acc: 0.9831
#
# Epoch 00184: saving model to fold_1.h5
# Epoch 185/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0423 - acc: 0.9834
#
# Epoch 00185: saving model to fold_1.h5
# Epoch 186/200
# 4400/4400 [==============================] - 4s 1ms/step - loss: 0.0430 - acc: 0.9832
#
# Epoch 00186: saving model to fold_1.h5
# Epoch 187/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0424 - acc: 0.9834
#
# Epoch 00187: saving model to fold_1.h5
# Epoch 188/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0425 - acc: 0.9834
#
# Epoch 00188: saving model to fold_1.h5
# Epoch 189/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0425 - acc: 0.9834
#
# Epoch 00189: saving model to fold_1.h5
# Epoch 190/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0424 - acc: 0.9834
#
# Epoch 00190: saving model to fold_1.h5
# Epoch 191/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0425 - acc: 0.9834
#
# Epoch 00191: saving model to fold_1.h5
# Epoch 192/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0430 - acc: 0.9832
#
# Epoch 00192: saving model to fold_1.h5
# Epoch 193/200
# 4400/4400 [==============================] - 4s 1ms/step - loss: 0.0431 - acc: 0.9831
#
# Epoch 00193: saving model to fold_1.h5
# Epoch 194/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0429 - acc: 0.9832
#
# Epoch 00194: saving model to fold_1.h5
# Epoch 195/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0431 - acc: 0.9832
#
# Epoch 00195: saving model to fold_1.h5
# Epoch 196/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0432 - acc: 0.9831
#
# Epoch 00196: saving model to fold_1.h5
# Epoch 197/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0432 - acc: 0.9831
#
# Epoch 00197: saving model to fold_1.h5
# Epoch 198/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0442 - acc: 0.9828
#
# Epoch 00198: saving model to fold_1.h5
# Epoch 199/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0468 - acc: 0.9818
#
# Epoch 00199: saving model to fold_1.h5
# Epoch 200/200
# 4400/4400 [==============================] - 5s 1ms/step - loss: 0.0484 - acc: 0.9813
#
# Epoch 00200: saving model to fold_1.h5
# acc: 96.24%
# 96.24% (+/- 0.00%)

# %%
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores[1:]), np.std(cvscores[1:])))
# Out:
# 96.51% (+/- 0.17%)

# %%
cvscores
# Out:
# [72.86070047388282,
#  96.40881197271229,
#  96.5627023499886,
#  96.35612498482564,
#  96.71673122518585,
#  96.41962918368253,
#  96.80616703727819,
#  96.34479267334098,
#  96.30505389049733,
#  96.65807177046732]

# %% [markdown]
# F) Output training results

# %% [markdown]
# G) Test against training and validation samples

# %%
# model = load_model('trainingonlr0.001.h5', custom_objects={'mean_iou': mean_iou})
# preds_train = model.predict(X_train[:int(X_train.shape[0]*0.8)], verbose=1)
# preds_val = model.predict(X_train[int(X_train.shape[0]*0.8):], verbose=1)

# preds_train_t = (preds_train > 0.5).astype(np.uint8)
# preds_val_t = (preds_val > 0.5).astype(np.uint8)

# %% [markdown]
# H) See predicted masks for training samples

# %%
# ix = random.randint(0, len(preds_train_t))
# imshow(X_train[ix])
# plt.show()
# imshow(np.squeeze(Y_train[ix]))
# plt.show()
# imshow(np.squeeze(preds_train_t[ix]))
# plt.show()

# %% [markdown]
# I) See predicted masks for validation data

# %%
# ix = random.randint(0, len(preds_val_t))
# imshow(X_train[int(X_train.shape[0]*0.7):][ix])
# plt.show()
# imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.7):][ix]))
# plt.show()
# imshow(np.squeeze(preds_val_t[ix]))
# plt.show()

# %% [markdown]
# J) Load model, testing data and check against trained network (if masks exist)

# %%
# model = load_model('your_model_name.h5', custom_objects={'mean_iou': mean_iou})
# ABD_PATH = '/home/lalzogbi/Documents/Skin_Datasets/allabdomen/val/skin_val2019/'
# MSK_PATH = '/home/lalzogbi/Documents/Skin_Datasets/allabdomen/val/annotations/'

# abd_ids = next(os.walk(ABD_PATH))[2]
# msk_ids = next(os.walk(MSK_PATH))[2]
# abd_ids.sort()
# msk_ids.sort()

# abd = np.zeros((len(abd_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
# msk = np.zeros((len(msk_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.uint8)

# sys.stdout.flush()
# for n, id_ in tqdm(enumerate(abd_ids), total=len(abd_ids)):
#     path = ABD_PATH + id_
#     img = imread(path)[:,:,:IMG_CHANNELS]
#     img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
#     abd[n] = img
    
# for n, id_ in tqdm(enumerate(msk_ids), total=len(msk_ids)):
#     path = MSK_PATH + id_
#     img = imread(path)
    
#     if img.ndim == 3:
#         img = img[:,:,1]
        
#     img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
#                                       preserve_range=True)
#     if (np.unique(img).size) > 2:
#         img = img > 30           # Important, Needed to make labels 0's and 1's only   
#     else:   
#         img = img > 0
#     img = img.astype(np.uint8)
#     msk[n] = img
    
# # Actual Predictions
# preds_test = model.predict(abd[:int(abd.shape[0])], verbose=1)

# # Threshold predictions
# preds_test_t = (preds_test > 0.5).astype(np.uint8)

# # Overall accuracy on abdomen pictures
# answer = acc_comp(msk, preds_test_t);

# # # Save results in a .npy file
# # a = np.reshape(answer[2],(100,1))
# # b = np.reshape(answer[3],(100,1))
# # c = np.reshape(answer[4],(100,1))
# # d = np.reshape(answer[5],(100,1))
# # g = np.concatenate([a,b,c,d],axis = 1)
# # np.save('your_file_name.npy',g)

# %% [markdown]
# K) Visualize results

# %%
# for j in range(len(abd_ids)):
#     print(j)
#     plt.show()
#     imshow(abd[j])
#     plt.show()
#     imshow(np.squeeze(preds_test_t[j]*255))
#     plt.show()
#     imshow(np.squeeze(msk[j]))

# %% [markdown]
# J') Load model, testing data and check against trained network (if masks do NOT exist)

# %%
# model = load_model('lydia.h5', custom_objects={'mean_iou': mean_iou})
# ABD_PATH = '/home/lalzogbi/Documents/Umbilicus_Skin_Detection/code/wounds/'

# abd_ids = next(os.walk(ABD_PATH))[2]
# abd_ids.sort()

# abd = np.zeros((len(abd_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)

# sys.stdout.flush()
# for n, id_ in tqdm(enumerate(abd_ids), total=len(abd_ids)):
#     path = ABD_PATH + id_
#     img = imread(path)[:,:,:IMG_CHANNELS]
#     img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
#     abd[n] = img
    
# # Actual Predictions
# preds_test = model.predict(abd[:int(abd.shape[0])], verbose=1)

# # Threshold predictions
# preds_test_t = (preds_test > 0.5).astype(np.uint8)

# %% [markdown]
# K') Visualize results

# %%
# for j in range(len(abd_ids)):
#     print(j)
#     plt.show()
#     imshow(abd[j])
#     plt.show()`
#     imshow(np.squeeze(preds_test_t[j]*255))
#     plt.show()
